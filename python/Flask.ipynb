# %% [markdown]
# ## 모델학습

# %%
# !python detect.py --weights ./runs/train/yolo0527/weights/best.pt  --source ./data/images/some_image.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='./data/images/some_image.jpg', update=False, view_img=False, weights=['./runs/train/yolo0527/weights/best.pt'])
# YOLOv5  v5.0-116-gaad99b6 torch 1.8.1+cpu CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21049761 parameters, 0 gradients, 50.3 GFLOPS
# image 1/1 C:\Users\smhrd\anaconda3\envs\yolov5\content\yolov5\data\images\some_image.jpg: 640x448 1 trash, Done. (0.282s)
# Results saved to runs\detect\exp20
# Done. (0.309s)

# %%
def yolo(weights, source):
    # !python detect.py

# %%
yolo("./runs/train/model0527_yolov5m_results/weights/best.pt", "./data/images/some_image.jpg")
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='data/images', update=False, view_img=False, weights='yolov5s.pt')
# image 1/20 C:\Users\smhrd\anaconda3\envs\yolov5\content\yolov5\data\images\some_image.jpg: 640x448 1 tv, 1 keyboard, Done. (0.143s)
# YOLOv5  v5.0-116-gaad99b6 torch 1.8.1+cpu CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# Traceback (most recent call last):
#   File "detect.py", line 184, in <module>
#     detect(opt=opt)
#   File "C:\Users\smhrd\anaconda3\envs\yolov5\lib\site-packages\torch\autograd\grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 60, in detect
#     for path, img, im0s, vid_cap in dataset:
# ...

# %%
pip install -U flask-cors

# %%
pip install flask-cors

# %% [markdown]
# ## 플라스크 연동

# %%
from flask import Flask,request,send_file, jsonify #플라스크 클래스 임포트
import base64
import os
import time
import pandas as pd
import json
from flask_cors import CORS, cross_origin

# %%
# from flask import Flask
# from flask_cors import CORS, cross_origin
# app = Flask(__name__)
# cors = CORS(app)
# app.config['CORS_HEADERS'] = 'Content-Type'

# @app.route("/")
# @cross_origin()
# def helloWorld():
#     return "Hello, cross-origin-world!"

# %%
app = Flask(__name__) # 내장변수 name을 이용해 서버를 구동시키는 객체 생성
CORS(app)
dog_emotion_columns = ['comfortable', 'happy', 'angry', 'sad']
cat_emotion_columns = ['comfortable', 'happy', 'angry', 'aggressive']

@app.route("/detectvid",methods=["GET","POST"])
def hello() :
    print("접속")
    filename = ""
    filename = request.args.get("filename")
    cord = request.args.get("cord")
    filename = filename.split("\\")[-1]
    
    filename = 'C:\\Users\\CGI\\Desktop\\vids\\' + filename
    
    if cord == 'D':
        # !python dog_detect.py --source {filename} --weights ./runs/train/dog/weights/best.pt  
    else:
        # !python cat_detect.py --source {filename} --weights ./runs/train/cat/weights/best.pt
    
    print("예측 끝")
    
    if cord == 'D':
        result = pd.read_csv('C:\\Users\\CGI\\Desktop\\dog_detect.csv')
        result = result[dog_emotion_columns]
        result_dict = {
                        dog_emotion_columns[0] : result[dog_emotion_columns[0]].count().astype(str), 
                        dog_emotion_columns[1] : result[dog_emotion_columns[1]].count().astype(str), 
                        dog_emotion_columns[2] : result[dog_emotion_columns[2]].count().astype(str), 
                        dog_emotion_columns[3] : result[dog_emotion_columns[3]].count().astype(str)
                      }
        
    else:
        result = pd.read_csv('C:\\Users\\CGI\\Desktop\\cat_detect.csv')
        result = result[cat_emotion_columns]
        result_dict = {
                        cat_emotion_columns[0] : result[cat_emotion_columns[0]].count().astype(str),
                        cat_emotion_columns[1] : result[cat_emotion_columns[1]].count().astype(str),
                        cat_emotion_columns[2] : result[cat_emotion_columns[2]].count().astype(str),
                        cat_emotion_columns[3] : result[cat_emotion_columns[3]].count().astype(str)
                      }
    result_dict['filename'] = filename
    result_dict = json.dumps(result_dict)
    print(result_dict)
    
    return result_dict


if __name__ == "__main__" : #.py파일에서 main 함수 역할
    app.run(host="211.223.136.21", port="7000")
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://211.223.136.21:7000/ (Press CTRL+C to quit)
# 접속
# YOLOv5  v5.0-327-gb60b62e torch 1.9.0+cpu CPU
#
# Fusing layers...
# C:\Users\CGI\anaconda3\envs\yolov5\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 224 layers, 7062001 parameters, 0 gradients, 16.4 GFLOPs
# 211.223.136.21 - - [06/Aug/2021 20:17:16] "POST /detectvid?filename=C:\fakepath\bangja02.mp4&cord=D HTTP/1.1" 200 -
# ...
